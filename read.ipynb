# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
headerList = ['year','jday','month','day','hour','minute','dt','zen',
              'dw_solar','qc_dwsolar','uw_solar','qc_uwsolar',
              'direct_n','qc_direct_n','diffuse','qc_diffuse',
              'dw_ir','qc_dwir','dw_casetemp','qc_dwcasetemp',
              'dw_dometemp','qc_dwdometemp','uw_ir','qc_uwir',
              'uw_casetemp','qc_uwcasetemp','uw_dometemp','qc_uwdometemp',
              'uvb','qc_uvb','par','qc_par','netsolar','qc_netsolar',
              'netir','qc_netir','totalnet','qc_totalnet',
              'temp','qc_temp','rh','qc_rh','windspd','qc_windspd',
              'winddir','qc_winddir','pressure','qc_pressure']

# %%
file_directory=("/home/rajeshprashanth/Desktop/surfrad/data/radiation/surfrad/bon/2015/")

# %%
files=[]
tempfiles = os.listdir(file_directory)

# %%
for file in tempfiles:
    files.append(file_directory+ file)

# %%
for file in files:
    data = pd.read_csv(file,skiprows=2,names=headerList,delimiter=r"\s+",index_col=False )
    df  = df.append(data)
# Out:
# /tmp/ipykernel_173082/4063205072.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df  = df.append(data)
# /tmp/ipykernel_173082/4063205072.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df  = df.append(data)
# /tmp/ipykernel_173082/4063205072.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df  = df.append(data)
# /tmp/ipykernel_173082/4063205072.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df  = df.append(data)
# /tmp/ipykernel_173082/4063205072.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df  = df.append(data)
# ...

# %%
df
# Out:
#       year jday month day hour minute      dt     zen  dw_solar qc_dwsolar  \
# 0     2015    1     1   1    0      0   0.000  105.10      -4.3          0
# 1     2015    1     1   1    0      1   0.017  105.28      -4.3          0
# 2     2015    1     1   1    0      2   0.033  105.47      -4.3          0
# 3     2015    1     1   1    0      3   0.050  105.65      -4.3          0
# 4     2015    1     1   1    0      4   0.067  105.83      -4.3          0
# ...    ...  ...   ...  ..  ...    ...     ...     ...       ...        ...
# 1435  2015   73     3  14   23     55  23.917   89.41       1.1          0
# 1436  2015   73     3  14   23     56  23.933   89.56       0.5          0
# 1437  2015   73     3  14   23     57  23.950   89.70       0.1          0
# 1438  2015   73     3  14   23     58  23.967   89.84      -0.4          0
# 1439  2015   73     3  14   23     59  23.983   89.97      -0.7          0
#
# ...

# %%
df.head()
# Out:
#    year jday month day hour minute     dt     zen  dw_solar qc_dwsolar  ...  \
# 0  2015    1     1   1    0      0  0.000  105.10      -4.3          0  ...
# 1  2015    1     1   1    0      1  0.017  105.28      -4.3          0  ...
# 2  2015    1     1   1    0      2  0.033  105.47      -4.3          0  ...
# 3  2015    1     1   1    0      3  0.050  105.65      -4.3          0  ...
# 4  2015    1     1   1    0      4  0.067  105.83      -4.3          0  ...
#
#    temp qc_temp    rh qc_rh  windspd qc_windspd  winddir qc_winddir  pressure  \
# 0  -7.3       0  67.2     0      5.1          0    231.9          0    1001.1
# 1  -7.4       0  67.6     0      5.2          0    229.9          0    1001.1
# 2  -7.4       0  67.7     0      5.1          0    233.1          0    1001.1
# 3  -7.4       0  67.4     0      5.5          0    232.6          0    1001.1
# 4  -7.3       0  67.0     0      5.7          0    232.9          0    1001.1
#
#   qc_pressure
# 0           0
# ...

# %%
df2 = df[(display(df.head(30)))]
# Out:
#     year jday month day hour minute     dt     zen  dw_solar qc_dwsolar  ...  \
# 0   2015    1     1   1    0      0  0.000  105.10      -4.3          0  ...
# 1   2015    1     1   1    0      1  0.017  105.28      -4.3          0  ...
# 2   2015    1     1   1    0      2  0.033  105.47      -4.3          0  ...
# 3   2015    1     1   1    0      3  0.050  105.65      -4.3          0  ...
# 4   2015    1     1   1    0      4  0.067  105.83      -4.3          0  ...
# 5   2015    1     1   1    0      5  0.083  106.01      -4.3          0  ...
# 6   2015    1     1   1    0      6  0.100  106.20      -4.3          0  ...
# 7   2015    1     1   1    0      7  0.117  106.38      -4.3          0  ...
# 8   2015    1     1   1    0      8  0.133  106.56      -4.3          0  ...
# 9   2015    1     1   1    0      9  0.150  106.75      -4.3          0  ...
# 10  2015    1     1   1    0     10  0.167  106.93      -4.3          0  ...
# ...
